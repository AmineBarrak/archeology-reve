# %% [markdown]
# # DBSCAN on public data, 5 classes
#
# This notebook contains code to perform DBSCAN and analysis on a dataset of job descriptions

# %%
#can be removed
from jupyterthemes import jtplot
jtplot.style()

# %% [markdown]
# ## 1. Load data

# %%
import pandas as pd

path = "./data/bman93/cleaned-data.csv"
df = pd.read_csv(path)

# %% [markdown]
# ## 2. Preprocessing
# Basically just taking a subset of the whole dataset that is already cleaned

# %%
# discard descriptions with fewer than 50 words
df = df[df['Description'].str.count(' ') > 50]

# %%
df.Query.value_counts()
# Out:
# Administrative Assistant                                      2993
# Customer Service Representative                               2777
# Project Manager                                               2345
# Business Analyst                                              2130
# Staff Accountant                                              2063
# Senior Accountant                                             1724
# Financial Analyst                                             1410
# Sales Representative                                          1371
# Maintenance Technician                                        1338
# Executive Assistant                                           1237
# Java Developer                                                1133
# Account Executive                                             1011
# Store Manager                                                  889
# Restaurant Manager                                             887
# ...

# %%
df = df.loc[df['Query'].isin(['Java Developer','Project Manager', 'Receptionist', 'Staff Accountant', 'Senior Accountant'])]
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            Query  \
# 6               6           388             388   Java Developer
# 7               7           395             395   Java Developer
# 10             10           707             707  Project Manager
# 11             11           713             713   Java Developer
# 13             13           728             728  Project Manager
# ...           ...           ...             ...              ...
# 31484       31484       1111009         1111009  Project Manager
# 31505       31505       1111692         1111692  Project Manager
# 31522       31522       1112470         1112470  Project Manager
# 31535       31535       1112869         1112869  Project Manager
# 31582       31582       1114584         1114584  Project Manager
#
#                                              Description
# 6      member web portal development team bhs informa...
# 7      hsi department commerce doc seeking fill short...
# ...

# %%
df.Query.value_counts()
# Out:
# Project Manager      2345
# Staff Accountant     2063
# Senior Accountant    1724
# Java Developer       1133
# Receptionist          885
# Name: Query, dtype: int64

# %%
# sample only 5000 descriptions
df = df.sample(n=5000)
df = df.reset_index(drop=True)
df.shape
# Out:
# (5000, 5)

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1              Query  \
# 0           9846        321057          321057   Staff Accountant
# 1           7971        260437          260437       Receptionist
# 2          18645        633857          633857    Project Manager
# 3          20834        708841          708841    Project Manager
# 4          27539        948536          948536  Senior Accountant
# ...          ...           ...             ...                ...
# 4995       16897        569291          569291       Receptionist
# 4996       17871        604682          604682    Project Manager
# 4997        6815        218707          218707   Staff Accountant
# 4998        7113        225697          225697  Senior Accountant
# 4999         211          5833            5833    Project Manager
#
#                                             Description
# 0     classification accountant staff ncompensation ...
# 1     classification receptionist switchboard ncompe...
# ...

# %%
df.Query.value_counts()
# Out:
# Project Manager      1435
# Staff Accountant     1250
# Senior Accountant    1068
# Java Developer        694
# Receptionist          553
# Name: Query, dtype: int64

# %% [markdown]
# Write / load data

# %%
# write
#df[['Query', 'Description']].to_csv("./data/bman93/cleaned-data-5classes-5000samples.csv")

# load
path = "./data/bman93/cleaned-data-5classes-5000samples.csv"
df = pd.read_csv(path)

# %% [markdown]
# ## 3. TF-IDF

# %%
import nltk
import re

# stopwords are already removed

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in df.Description:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'description': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 707049 items in vocab_frame

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, #stop_words=stopwords,
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(df.Description) #fit the vectorizer to synopses

print(tfidf_matrix.shape)
# Out:
# (5000, 106)

# %% [markdown]
# ## 4. Clustering with DBSCAN

# %%
from sklearn.cluster import DBSCAN

EPS = 0.75 # maximal distance 
MIN_SAMPLES = 10 # minimal amount of samples to form a cluster

clustering = DBSCAN(eps=EPS, min_samples=MIN_SAMPLES).fit(tfidf_matrix)
clusters = clustering.labels_.tolist()
y_pred_clus = clustering.fit_predict(tfidf_matrix)

# %% [markdown]
# ## 5. Visualize clusters

# %% [markdown]
# Use SVD to reduce dimensions of points to only 2

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)
data_2d = svd.fit_transform(tfidf_matrix)
data_2d.shape
# Out:
# (5000, 2)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(10,10))
scatter = plt.scatter(data_2d[:,0], data_2d[:,1], c=y_pred_clus)
plt.legend(*scatter.legend_elements())
plt.title("5 classes DBSCAN clusters")
plt.savefig("figures/5ClassesDBSCANClusters")
plt.show()

# %% [markdown]
# ## Visualize actual classes

# %%
df['Class'] = pd.factorize(df['Query'])[0] + 1
df
# Out:
#       Unnamed: 0              Query  \
# 0              0   Staff Accountant
# 1              1    Project Manager
# 2              2    Project Manager
# 3              3  Senior Accountant
# 4              4       Receptionist
# ...          ...                ...
# 4995        4995     Java Developer
# 4996        4996   Staff Accountant
# 4997        4997   Staff Accountant
# 4998        4998    Project Manager
# 4999        4999    Project Manager
#
#                                             Description  Class
# 0     classification accountant staff ncompensation ...      1
# 1     project management support assistant provide l...      2
# 2     new era roofing rfrom beginning 2000 tecta ame...      2
# 3     classification accountant senior ncompensation...      3
# 4     receptionist position features immediate need ...      4
# ...                                                 ...    ...
# 4995  rcreates user information solutions developing...      5
# ...

# %%
df.Class.unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
CLASSES = ['Staff Accountant', 'Project Manager', 'Senior Accountant', 'Receptionist', 'Java Developer']

# %%
figure(figsize=(10,10))
scatter = plt.scatter(data_2d[:,0], data_2d[:,1], c=df['Class'])
plt.legend([*scatter.legend_elements()[0]], CLASSES)
plt.title("5 classes ground truth labels")
plt.savefig("figures/5ClassesGroundTruthLabels")
plt.show()

# %% [markdown]
# ## 6. Number of descriptions of each class of each cluster

# %%
jobdes = { 'Query': df.Query, 'Description': df.Description, 'cluster': clusters }
frame = pd.DataFrame(jobdes, columns = ['Query', 'Description', 'cluster'])

frame
# Out:
#                   Query                                        Description  \
# 0      Staff Accountant  classification accountant staff ncompensation ...
# 1       Project Manager  project management support assistant provide l...
# 2       Project Manager  new era roofing rfrom beginning 2000 tecta ame...
# 3     Senior Accountant  classification accountant senior ncompensation...
# 4          Receptionist  receptionist position features immediate need ...
# ...                 ...                                                ...
# 4995     Java Developer  rcreates user information solutions developing...
# 4996   Staff Accountant  rassist finance team gathering recording analy...
# 4997   Staff Accountant  classification accountant staff ncompensation ...
# 4998    Project Manager  participate customer site visits proposal deve...
# 4999    Project Manager  outstanding opportunity project manager backgr...
#
#       cluster
# 0           0
# 1           0
# 2          -1
# ...

# %%
frame.cluster.value_counts()
# Out:
#  0    3306
# -1    1643
#  2      39
#  1      12
# Name: cluster, dtype: int64

# %%
clusters_classes_counts = []
for c_num in frame.cluster.unique():
    print('CLUSTER: ', c_num)
    cluster_frame = frame[frame['cluster'] == c_num]
    print(cluster_frame.Query.value_counts())
    clusters_classes_counts.append([c_num, cluster_frame.Query.value_counts()])
    print('------------')
# Out:
# CLUSTER:  0
# Project Manager      1164
# Staff Accountant      914
# Senior Accountant     748
# Java Developer        471
# Receptionist            9
# Name: Query, dtype: int64
# ------------
# CLUSTER:  -1
# Receptionist         479
# Staff Accountant     349
# Senior Accountant    329
# Project Manager      287
# Java Developer       199
# Name: Query, dtype: int64
# ------------
# CLUSTER:  1
# Receptionist    12
# Name: Query, dtype: int64
# ------------
# CLUSTER:  2
# Receptionist         27
# Staff Accountant     10
# Senior Accountant     1
# Project Manager       1
# Name: Query, dtype: int64
# ------------

# %% [markdown]
# Here we can say that each cluster would be used to predict class in the following manner:
#     - cluster 0 : Project Manager
#     - cluster 1 : Receptionist
#     - cluster 2 : Receptionist

# %%
for counts in clusters_classes_counts:
    plt.title('Cluster: ' + str(counts[0]))
    counts[1].plot(kind = 'bar')
    plt.show()

# %% [markdown]
# ## 6. Comparing words in clusters

# %%
def most_common_words(df, n_words):
    words = pd.Series(' '.join(df['Description']).lower().split()).value_counts()[:n_words]
    return words

# %%
clus_words_counts = []
for c_num in frame.cluster.unique():
    cluster_frame = frame[frame['cluster'] == c_num]
    words = most_common_words(cluster_frame, 10)
    clus_words_counts.append([c_num, words])

# %%
for counts in clus_words_counts:
    plt.title('Cluster: ' + str(counts[0]))
    counts[1].plot(kind = 'bar')
    plt.show()

# %% [markdown]
# ### Comparing words according to tf idf scores

# %%
# todo

# %% [markdown]
# ## 7. F-score with labelled classes

# %% [markdown]
# Class map:
#
#     1: Staff Accountant
#     2: Project Manager
#     3: Senior Accountant
#     4: Receptionist
#     5: Java Developer
#
# Cluster map:
#
#     -1 : 0 : noisy samples
#      0 : 2 : Project Manager
#      1 : 4 : Receptionist
#      2 : 4 : Receptionist

# %%
def to_pred(cluster_num):
    if cluster_num == -1:
        return 0 
    elif cluster_num == 0:
        return 2
    elif cluster_num == 1:
        return 4
    elif cluster_num == 2:
        return 4

# %%
frame.head()
# Out:
#                Query                                        Description  \
# 0   Staff Accountant  classification accountant staff ncompensation ...
# 1    Project Manager  project management support assistant provide l...
# 2    Project Manager  new era roofing rfrom beginning 2000 tecta ame...
# 3  Senior Accountant  classification accountant senior ncompensation...
# 4       Receptionist  receptionist position features immediate need ...
#
#    cluster
# 0        0
# 1        0
# 2       -1
# 3       -1
# 4       -1

# %%
y_pred = frame.apply(lambda row: to_pred(row.cluster), axis=1)
y_true = df.Class

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

precision_score(y_true, y_pred, average='weighted')
# Out:
# /home/fabrice/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.18284609800362978

# %%
recall_score(y_true, y_pred, average='weighted')
# Out:
# /home/fabrice/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.2406

# %%
from sklearn.metrics import f1_score

f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.15631079296788072

# %%
f1_score(y_true, y_pred, average='macro')
# Out:
# 0.10403821791308321

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_true, y_pred)
# Out:
# 0.2406

# %% [markdown]
# ## 8. Visualize Clusters Centers

# %%
centers = []
for c_num in frame.cluster.unique():
    indexes = frame[frame['cluster'] == c_num].index.tolist()
    c_rows = tfidf_matrix[indexes,:]
    centers.append(c_rows.mean(axis=0))

# %%
from scipy.sparse import vstack
import numpy as np

new_matrix = vstack([tfidf_matrix, *centers])

data_2d = svd.fit_transform(new_matrix)

y_pred_clus_with_center = np.append(y_pred_clus, np.arange(len(centers), 2*len(centers)))

figure(figsize=(10,10))
scatter = plt.scatter(data_2d[:,0], data_2d[:,1], c=y_pred_clus_with_center)
plt.legend(scatter.legend_elements()[0],["Noisy samples", "Cluster 0", "Cluster 1", "Cluster 2", "Center noisy", "Center 0", "Center 1", "Center 2"])
plt.title("DBSCAN clusters with centers ")
plt.show()

# %% [markdown]
# ## 9. Other performance evaluation

# %% [markdown]
# Other clustering performance metrics suggested by sklearn
#
# https://scikit-learn.org/stable/modules/clustering.html#clustering-performance-evaluation

# %%
from sklearn import metrics

# %% [markdown]
# Adjusted Rand index -> takes true labels into account

# %%
metrics.adjusted_rand_score(y_true, y_pred)
# Out:
# 0.0746923464146872

# %% [markdown]
# Silhouette score -> does not take true labels into account, but will naturally favor higher convex clusters than density based clusters of DBSCAN

# %%
metrics.silhouette_score(tfidf_matrix, frame.cluster, metric='euclidean')
# Out:
# 0.010817132300462816

# %% [markdown]
# ### All metrics, Ignoring cluster -1, noisy samples

# %%
non_noisy_indexes = frame[frame['cluster'] != -1].index.tolist()

y_true = y_true[non_noisy_indexes]
y_pred = y_pred[non_noisy_indexes]
tfidf_matrix = tfidf_matrix[non_noisy_indexes]

# %% [markdown]
# #### F-score and accuracy

# %%
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.1919632801856822

# %%
accuracy_score(y_true, y_pred)
# Out:
# 0.3583556747095621

# %% [markdown]
# #### ARI

# %%
metrics.adjusted_rand_score(y_true, y_pred)
# Out:
# 0.016456170323721327

# %% [markdown]
# #### Silhouette

# %%
metrics.silhouette_score(tfidf_matrix, frame.cluster[non_noisy_indexes], metric='euclidean')
# Out:
# 0.06019083622916663
